# %%
with open('punarchi.txt', 'r+', encoding= 'utf-8') as f:
    contents = f.read()

print(contents)
# Out:
# பலபல => பல+பல
# சிலசில => சில+சில
# பலப்பல => பல+பல
# சிலச்சில => சில+சில
# பலற்பல => பல+பல
# சிலற்சில => சில+சில
# பல்கலை => பல+கலை
# பல்சாலை => பல+சாலை
# பஃதொடை => பல+தொடை
# பன்மலர் => பல+மலர்
# பன்னாடு => பல+நாடு
# பல்வேண்டி => பல+வேண்டி
# பல்லரண் => பல+அரண்
# சில்சொல் => சில+சொல்
# சின்மலர் => சில+மலர்
# சில்வளை => சில+வளை
# சில்லணி => சில+அணி
# வடகிழக்கு => வடக்கு+கிழக்கு
# வடமேற்கு => வடக்கு+மேற்கு
# வடவேங்கடம் => வடக்கு+வேங்கடம்
# குடதிசை => குடக்கு+திசை
# குணதிசை => குணக்கு+திசை
# தென்கிழக்கு => தெற்கு+கிழக்கு
# தென்மேற்கு => தெற்கு+மேற்கு
# தென்குமரி => தெற்கு+குமரி
# தென்பாண்டி => தெற்கு+பாண்டி
# மேல்காற்று => மேற்கு+காற்று
# மேலூர் => மேற்கு+ஊர்
# கீழ்கடல் => கிழக்கு+கடல்
# கீழ்நாடு => கிழக்கு+நாடு
# நல்லன் => நன்மை+அன்
# வெண்பட்டு => வெண்மை+பட்டு
# வெண்குடை => வெண்மை+குடை
# செம்மலர் => செம்மை+மலர்
# பெரியன் => பெருமை+அன்
# சிறியன் => சிறுமை+அன்
# மூதூர் => முதுமை+ஊர்
# பாசி => பசுமை+இ
# பைங்கொடி => பசுமை+கொடி
# பைந்தார் => பசுமை+தார்
# சிற்றூர் => சிறுமை+ஊர்
# ...

# %%
import csv

asta_file_path = 'punarchi.txt'
out_csv = 'out.csv'

with open(asta_file_path, 'r', encoding='utf-8') as f:
    asta_data = f.readlines()

# %%
asta_data[2700]
# Out:
# 'கதிர்மேகம் => கதிர் + மேகம்\n'

# %%
with open(out_csv, 'w+', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    csv_writer.writerow(['Text', 'Marked'])

    for line in asta_data:
        text, marked = line.split(' => ')
        csv_writer.writerow([text.strip(), marked.strip()])

# %%
import pandas as pd

df = pd.read_csv('out.csv')

df
# Out:
#              Text          Marked
# 0            பலபல           பல+பல
# 1          சிலசில         சில+சில
# 2          பலப்பல           பல+பல
# 3        சிலச்சில         சில+சில
# 4          பலற்பல           பல+பல
# ...           ...             ...
# 2879      பூதேடல்      பூ + தேடல்
# 2880     நிலம்பனி     நிலம் + பனி
# 2881  மலர்விளக்கு  மலர் + விளக்கு
# 2882    கதிர்பழம்    கதிர் + பழம்
# 2883      பசுப்பூ        பசு + பூ
#
# [2884 rows x 2 columns]

# %%
out_map_csv = 'out_map.csv'

def char_label_mapping(text, labels):
    text_chars = [char_t for char_t in text]
    marked_list = [char_i for char_i in labels]
    result = []
    
    for i, char in enumerate(marked_list):
        if char == "+":
            result.append(' SP')
        else:
            result.append(' NSP')
    
    return ''.join(result)

with open(out_map_csv, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    csv_writer.writerow(['Text', 'Marked', 'Labels'])  
    
    for line in asta_data:
        if ' => ' in line:
            text, marked = line.split(' => ')
            print(text.strip())
            print(marked.strip())
            labels = char_label_mapping(text.strip(), marked.strip())
            csv_writer.writerow([text.strip(), marked.strip(), labels])
        else:
            print(f"Skipping line due to incorrect format: {line}")
# Out:
# பலபல
# பல+பல
# சிலசில
# சில+சில
# பலப்பல
# பல+பல
# சிலச்சில
# சில+சில
# பலற்பல
# பல+பல
# சிலற்சில
# சில+சில
# பல்கலை
# பல+கலை
# பல்சாலை
# பல+சாலை
# பஃதொடை
# பல+தொடை
# பன்மலர்
# பல+மலர்
# பன்னாடு
# பல+நாடு
# பல்வேண்டி
# பல+வேண்டி
# பல்லரண்
# பல+அரண்
# சில்சொல்
# சில+சொல்
# சின்மலர்
# சில+மலர்
# சில்வளை
# சில+வளை
# சில்லணி
# சில+அணி
# வடகிழக்கு
# வடக்கு+கிழக்கு
# வடமேற்கு
# வடக்கு+மேற்கு
# வடவேங்கடம்
# வடக்கு+வேங்கடம்
# குடதிசை
# குடக்கு+திசை
# குணதிசை
# குணக்கு+திசை
# தென்கிழக்கு
# தெற்கு+கிழக்கு
# தென்மேற்கு
# தெற்கு+மேற்கு
# தென்குமரி
# தெற்கு+குமரி
# தென்பாண்டி
# தெற்கு+பாண்டி
# மேல்காற்று
# மேற்கு+காற்று
# மேலூர்
# மேற்கு+ஊர்
# கீழ்கடல்
# கிழக்கு+கடல்
# கீழ்நாடு
# கிழக்கு+நாடு
# நல்லன்
# நன்மை+அன்
# வெண்பட்டு
# வெண்மை+பட்டு
# வெண்குடை
# வெண்மை+குடை
# செம்மலர்
# செம்மை+மலர்
# பெரியன்
# பெருமை+அன்
# சிறியன்
# சிறுமை+அன்
# மூதூர்
# முதுமை+ஊர்
# பாசி
# பசுமை+இ
# பைங்கொடி
# பசுமை+கொடி
# பைந்தார்
# பசுமை+தார்
# சிற்றூர்
# சிறுமை+ஊர்
# வெற்றிலை
# வெறுமை+இலை
# வெவ்வேல்
# வெம்மை+வேல்
# ...

# %%
 import pandas
 dataframe_df = pandas.read_csv('out_map.csv')
 
 dataframe_df
# Out:
#              Text          Marked  \
# 0            பலபல           பல+பல
# 1          சிலசில         சில+சில
# 2          பலப்பல           பல+பல
# 3        சிலச்சில         சில+சில
# 4          பலற்பல           பல+பல
# ...           ...             ...
# 2879      பூதேடல்      பூ + தேடல்
# 2880     நிலம்பனி     நிலம் + பனி
# 2881  மலர்விளக்கு  மலர் + விளக்கு
# 2882    கதிர்பழம்    கதிர் + பழம்
# 2883      பசுப்பூ        பசு + பூ
#
#                                                  Labels
# 0                                    NSP NSP SP NSP NSP
# 1                            NSP NSP NSP SP NSP NSP NSP
# 2                                    NSP NSP SP NSP NSP
# 3                            NSP NSP NSP SP NSP NSP NSP
# 4                                    NSP NSP SP NSP NSP
# ...                                                 ...
# 2879             NSP NSP NSP SP NSP NSP NSP NSP NSP NSP
# 2880         NSP NSP NSP NSP NSP NSP SP NSP NSP NSP NSP
# ...

# %%
with open('punarchi_mapped.txt', 'w+') as f:
    lines = []
    for i in range(dataframe_df.shape[0]):
        lines.append(dataframe_df['Text'][i] + dataframe_df['Labels'][i] + '\n')
    f.writelines(lines)
